# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(10)
y = np.random.rand(10)
plt.plot(x, y, 'x')
a = 2000/3
b = 1000/3
print ("%.2f" %a, "%.2f" %b)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.text(0.5, 0.5, "a value = %.2f" %a, horizontalalignment='center', verticalalignment='center')
# Out:
# 666.67 333.33
# Text(0.5, 0.5, 'a value = 666.67')
