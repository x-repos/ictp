# %% [markdown]
# The algorithm is unstable if $ b_j - a_j\times F_{j-1}$ is zero

# %%
import numpy as np
import matplotlib.pyplot as plt

# func
def func(x):
    """Function"""
    if x > .5:
        return 273.15 + 20 - 20*x + np.sin(50*np.pi*x)
    else:
        return 273.15 + 20*x + np.sin(50*np.pi*x)

# tridiagonal for the system of equations
def tridiagonal(a,b,c,d):
    """
    Tridiagonal matrix algorithm
    a, b, c are matrices for tridiagonal elements
    d is rhs matrix
    """
    n = len(d)
    c1 = np.zeros(n-1)
    d1 = np.zeros(n)
    c1[0] = c[0]/b[0]
    d1[0] = d[0]/b[0]
    for i in range(1, n-1):
        c1[i] = c[i]/(b[i]-a[i]*c1[i-1])
    for i in range(1, n):
        d1[i] = (d[i] - a[i]*d1[i-1])/(b[i] - a[i]*c1[i-1])
    for i in reversed(range(n-1)):
        d1[i] = d1[i] - c1[i]*d1[i+1]
    return d1

# main loop
def diffusion(x0, y0, diaValue):
    # create matrix for Thomas algorithm
    
    sz = len(x0); t = 0
    n = sz - 2
    a = np.ones(n)  * diaValue[0]
    b = np.ones(n)  * diaValue[1]
    c = np.ones(n-1)* diaValue[2]
    d = y0[1:sz-1].copy()
    while t < duration:
        d[0] = d[0] - diaValue[0]*dboundary
        d[n-1] = d[n-1] - diaValue[2]*dboundary
        d = tridiagonal(a,b,c,d)
        if t%tinterval < dt:
            plt.plot(x0, y0, label="$\phi$(" + str(int(np.floor(t/3600))) + "h)")
        y0[1:sz-1] = d[:].copy()
        t = t + dt
    plt.legend()
    plt.grid()

# initial condition
dt = 360; k = 2.9e-5; dx = 0.01 # control vars
# NOTE: no limit of t
dboundary = 273.15 # dirichlet boundary
tinterval = 3600; duration = 3600*6 + 10 # time
x0 = np.arange(0, 1+dx, dx)
y0 = np.vectorize(func)(x0)
y0[0] = dboundary; y0[-1] = dboundary
alpha = k*dt/dx**2
diaValue = [-alpha, 1+2*alpha, -alpha]

# run
diffusion(x0, y0, diaValue)
