# %%
from obspy.clients.fdsn import RoutingClient
from obspy import UTCDateTime

starttime = UTCDateTime('2015-09-16 22:54:33')
endtime = UTCDateTime('2015-09-16 22:55:33')
rsClient = RoutingClient("eida-routing",
                         credentials={'EIDA_TOKEN': '/home/x/ictp/thesis-ictp/token/eidatoken'})
st = rsClient.get_waveforms(network="", station="B02" ,starttime=starttime, endtime=endtime)
st.plot();
# Out:
# /home/x/miniconda3/envs/obspy/lib/python3.9/site-packages/obspy/io/stationxml/core.py:96: UserWarning: The StationXML file has version 1.2, ObsPy can read versions (1.0, 1.1). Proceed with caution.
#   warnings.warn("The StationXML file has version %s, ObsPy can "
